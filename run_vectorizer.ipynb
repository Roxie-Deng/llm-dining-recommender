# %%
import os
print(os.getcwd())
# Out:
# d:\Programming\LLMRec

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(
    df_without,
    config_path="configs/data_config.yaml",
    output_path="D:/Programming/LLMRec/data/engineered/without_review/business_embeddings_without_review"
)
# Out:
# Starting business vectorization (without reviews)...
# Step 1: Encoding text features...
# Loading sentence transformer model: all-MiniLM-L6-v2
# Encoding text column: description
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# Step 3: Encoding boolean features...
# Encoding boolean column: OutdoorSeating
# Encoding boolean column: RestaurantsReservations
# Step 4: Normalizing numerical features...
# Normalizing numerical column: normalized_price
# Step 5: Creating TF-IDF features...
# Creating TF-IDF features from column: categories
# Step 6: Combining features...
# Vectorization complete! Feature matrix shape: (995, 496)
# Number of features: 14
# Vectorizer saved to: D:/Programming/LLMRec/data/engineered/without_review/business_embeddings_without_review_vectorizer.pkl
# Embeddings saved to: D:/Programming/LLMRec/data/engineered/without_review/business_embeddings_without_review
# (array([[ 0.05121014, -0.01821283,  0.01625829, ...,  0.        ,
# ...

# %%
from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review

df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
create_business_embeddings_with_review(
    df_with_review,
    config_path="configs/data_config.yaml",
    output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
)
# Out:
# Loading SentenceTransformer model for review_tip: paraphrase-MiniLM-L6-v2
# Loading SentenceTransformer model for description: all-MiniLM-L6-v2
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 4
#       1 from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review
#       3 df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
# ----> 4 create_business_embeddings_with_review(
#       5     df_with_review,
#       6     config_path="configs/data_config.yaml",
#       7     output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
#       8 )
#
# ...

# %%
from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review

df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
create_business_embeddings_with_review(
    df_with_review,
    config_path="configs/data_config.yaml",
    output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
)
# Out:
# Loading SentenceTransformer model for review_tip: paraphrase-MiniLM-L6-v2
# Loading SentenceTransformer model for description: all-MiniLM-L6-v2
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[6], line 4
#
#       1 from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review
#
#       3 df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
#
# ----> 4 create_business_embeddings_with_review(
#
#       5     df_with_review,
#
#       6     config_path="configs/data_config.yaml",
#
#       7     output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
#
#       8 )
#
#
#
# ...

# %%
from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review

df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
create_business_embeddings_with_review(
    df_with_review,
    config_path="configs/data_config.yaml",
    output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
)
# Out:
# Loading SentenceTransformer model for review_tip: paraphrase-MiniLM-L6-v2
# Loading SentenceTransformer model for description: all-MiniLM-L6-v2
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
#
# KeyError                                  Traceback (most recent call last)
#
# Cell In[6], line 4
#
#       1 from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review
#
#       3 df_with_review = pd.read_json("data/engineered/with_review/extracted_features_with_review.json", encoding="utf-8")
#
# ----> 4 create_business_embeddings_with_review(
#
#       5     df_with_review,
#
#       6     config_path="configs/data_config.yaml",
#
#       7     output_dir="D:/Programming/LLMRec/data/engineered/with_review/business_embeddings_with_review"
#
#       8 )
#
#
#
# ...

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[3], line 6
#
#       3 sys.path.append(os.path.abspath('.'))
#
#       5 import pandas as pd
#
# ----> 6 from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review
#
#       8 df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
#
#       9 create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[3], line 6
#
#       3 sys.path.append(os.path.abspath('.'))
#
#       5 import pandas as pd
#
# ----> 6 from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review
#
#       8 df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
#
#       9 create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[3], line 6
#
#       3 sys.path.append(os.path.abspath('.'))
#
#       5 import pandas as pd
#
# ----> 6 from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review
#
#       8 df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
#
#       9 create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[3], line 6
#
#       3 sys.path.append(os.path.abspath('.'))
#
#       5 import pandas as pd
#
# ----> 6 from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review
#
#       8 df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
#
#       9 create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
import sys
import os
sys.path.append(os.path.abspath('.'))

import pandas as pd
from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review

df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
# Out:
# ---------------------------------------------------------------------------
#
# ModuleNotFoundError                       Traceback (most recent call last)
#
# Cell In[3], line 6
#
#       3 sys.path.append(os.path.abspath('.'))
#
#       5 import pandas as pd
#
# ----> 6 from src.feature_engineering.vectorizer_without_review import create_business_embeddings_without_review
#
#       8 df_without = pd.read_json("data/engineered/without_review/extracted_features_without_review.json", encoding="utf-8")
#
#       9 create_business_embeddings_without_review(df_without, config_path="configs/data_config.yaml")
#
#
#
# ModuleNotFoundError: No module named 'src'

# %%
import pandas as pd
from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_review

df = pd.read_json("data/engineered/with_review/extracted_features_with_text.json", encoding="utf-8")
create_business_embeddings_with_review(df, config_path="configs/data_config.yaml")

# %%
# WITH SUMMARY
import pandas as pd
from src.feature_engineering.vectorizer_with_review import create_business_embeddings_with_summary

df_summary = pd.read_json("data/engineered/with_summary/extracted_features_with_summary.json", encoding="utf-8")
create_business_embeddings_with_summary(df_summary, config_path="configs/data_config.yaml")
